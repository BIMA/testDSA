# %%
# Import dataset
import pandas as pd
import numpy as np

dataset_lokasi = pd.read_csv('catatan_lokasi.csv')
dataset_profil = pd.read_csv('data_profil.csv')
dataset_id = dataset_profil.merge(dataset_lokasi, on = 'id', how = 'inner')

# Kemungkinan pertanyaan
''' Pada tanggal berapa (salah satu divisi disebut) sering berada di suatu tempat tertentu?'''
print('Pada tanggal berapa (salah satu divisi disebut) sering berada di suatu tempat tertentu?')
# Coding
tempat = dataset_id.groupby('lokasi_dominan')
while True:
    dimana = str(input('Masukan tempat: '))
    data_tempat = tempat.get_group(dimana)
    print(data_tempat.groupby('divisi').size())
    lanjut = str(input('lanjut Y/N: '))
    if lanjut == 'n':
        break
# Out:
# Pada tanggal berapa (salah satu divisi disebut) sering berada di suatu tempat tertentu?
# Masukan tempat: Kota Bekasi
#
# lanjut Y/N: n

# %%
# Import dataset
import pandas as pd
import numpy as np

dataset_lokasi = pd.read_csv('catatan_lokasi.csv')
dataset_profil = pd.read_csv('data_profil.csv')
dataset_id = dataset_profil.merge(dataset_lokasi, on = 'id', how = 'inner')

# Kemungkinan pertanyaan
''' Pada tanggal berapa (salah satu divisi disebut) sering berada di suatu tempat tertentu?'''
print('Pada tanggal berapa (salah satu divisi disebut) sering berada di suatu tempat tertentu?')
# Coding
tempat = dataset_id.groupby('lokasi_dominan')
while True:
    berapa_umur = str(input('Masukan tempat: '))
    data_umur = tempat.get_group(berapa_umur)
    print(data_umur.groupby('umur').size())
    lanjut = str(input('lanjut Y/N: '))
    if lanjut == 'n':
        break
# Out:
# Pada tanggal berapa (salah satu divisi disebut) sering berada di suatu tempat tertentu?
# Masukan tempat: Kota Bekasi
# umur
# 22     3
# 23    23
# 25    37
# 27     2
# 28    21
# 29     3
# 30    13
# 31     5
# 32    15
# 33    18
# 34    23
# 35     2
# dtype: int64
# lanjut Y/N: n

# %%
# Import dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

dataset_lokasi = pd.read_csv('catatan_lokasi.csv')
dataset_profil = pd.read_csv('data_profil.csv')
dataset_id = dataset_profil.merge(dataset_lokasi, on = 'id', how = 'inner')
dataset_gabung = dataset_profil.merge(dataset_lokasi)

sns.countplot(x='jenis_kelamin', data=dataset_gabung);
plt.title('Distribution of Gender');

# %%
# Create a histogram of ages
dataset_gabung.hist('umur', bins=35)
plt.title('Distribution of Age')
plt.xlabel('Age')

# %%
# Out:
# Text(0.5, 1.0, 'Distribution of Location')
